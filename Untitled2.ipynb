# %% [markdown]
# <a href="https://colab.research.google.com/github/hazipeera/ARTIFICIAL-INTELLIGENCE/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def tower_of_hanoi(n, source, auxiliary, destination):

    if n == 1:
        print("Move disk 1 from", source, "to", destination)
        return

    tower_of_hanoi(n - 1, source, destination, auxiliary)

    print("Move disk", n, "from", source, "to", destination)

    tower_of_hanoi(n - 1, auxiliary, source, destination)


n = int(input("Enter number of disks: "))

tower_of_hanoi(n, "A", "B", "C")
# Out:
# Enter number of disks: 5
# Move disk 1 from A to C
# Move disk 2 from A to B
# Move disk 1 from C to B
# Move disk 3 from A to C
# Move disk 1 from B to A
# Move disk 2 from B to C
# Move disk 1 from A to C
# Move disk 4 from A to B
# Move disk 1 from C to B
# Move disk 2 from C to A
# Move disk 1 from B to A
# Move disk 3 from C to B
# Move disk 1 from A to C
# Move disk 2 from A to B
# Move disk 1 from C to B
# Move disk 5 from A to C
# Move disk 1 from B to A
# Move disk 2 from B to C
# Move disk 1 from A to C
# Move disk 3 from B to A
# Move disk 1 from C to B
# Move disk 2 from C to A
# Move disk 1 from B to A
# Move disk 4 from B to C
# Move disk 1 from A to C
# Move disk 2 from A to B
# Move disk 1 from C to B
# Move disk 3 from A to C
# Move disk 1 from B to A
# Move disk 2 from B to C
# Move disk 1 from A to C

# %%
def tower_of_hanoi(n, source, auxiliary, destination, radius, rods):

    if n == 1:
        ring = radius[0]
        print("Move ring with radius", ring, "from", source, "to", destination)

        rods[source].remove(ring)
        rods[destination].append(ring)
        return

    tower_of_hanoi(n - 1, source, destination, auxiliary, radius, rods)

    ring = radius[n - 1]
    print("Move ring with radius", ring, "from", source, "to", destination)

    rods[source].remove(ring)
    rods[destination].append(ring)

    tower_of_hanoi(n - 1, auxiliary, source, destination, radius, rods)


n = int(input("Enter number of rings: "))

radius = list(map(float, input("Enter radii separated by commas: ").split(",")))

if len(radius) != n:
    print("Number of radii must be equal to number of rings.")
else:
    rods = {
        "A": radius.copy(),
        "B": [],
        "C": []
    }

    tower_of_hanoi(n, "A", "B", "C", radius, rods)

    print("\nFinal order:")
    print("Rod A:", rods["A"])
    print("Rod B:", rods["B"])
    print("Rod C:", rods["C"])
# Out:
# Enter number of rings: 4
# Enter radii separated by commas: 5,3,6,1
# Move ring with radius 5.0 from A to B
# Move ring with radius 3.0 from A to C
# Move ring with radius 5.0 from B to C
# Move ring with radius 6.0 from A to B
# Move ring with radius 5.0 from C to A
# Move ring with radius 3.0 from C to B
# Move ring with radius 5.0 from A to B
# Move ring with radius 1.0 from A to C
# Move ring with radius 5.0 from B to C
# Move ring with radius 3.0 from B to A
# Move ring with radius 5.0 from C to A
# Move ring with radius 6.0 from B to C
# Move ring with radius 5.0 from A to B
# Move ring with radius 3.0 from A to C
# Move ring with radius 5.0 from B to C
#
# Final order:
# Rod A: []
# Rod B: []
# Rod C: [1.0, 6.0, 3.0, 5.0]
